# %%
#getting pymysql and pandas libraires

import pymysql
import pandas as pd

# %%
#connecting database to the Jupyter notebook

# %%capture
# %load_ext sql
# %sql mysql+mysqldb://Akil:Akilan26@localhost/furniture_sales_db

# %%
#select total sales from database

# %%sql
SELECT * FROM sales;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 60 rows affected.
# [(1, '1/2/19 4:53', 'Chair', 1200, 'Visa', 'Bettina Schmidt', 'Parkville', 'MO', 'United States', '1/2/19 4:42', '1/2/19 7:49', 39.195, -94.68194, 2, None),
#  (2, '1/2/19 13:08', 'Chair', 1200, 'Mastercard', 'Federica Villanueva', 'Astoria', 'OR', 'United States', '1/1/19 16:21', '1/3/19 12:32', 46.18806, -123.83, 3, None),
#  (3, '1/4/19 12:56', 'Couch', 3600, 'Visa', 'Gerd Winslow', 'Cahaba Heights', 'AL', 'United States', '11/15/18 15:47', '1/4/19 12:45', 33.52056, -86.8025, 1, None),
#  (4, '1/4/19 13:19', 'Chair', 1200, 'Visa', 'Laurence Arabia', 'Mickleton', 'NJ', 'United States', '9/24/18 15:19', '1/4/19 13:04', 39.79, -75.23806, 3, None),
#  (5, '1/4/19 20:11', 'Chair', 1200, 'Mastercard', 'Fleur Barnes', 'Peoria', 'IL', 'United States', '1/3/19 9:38', '1/4/19 19:45', 40.69361, -89.58889, 2, None),
#  (6, '1/2/19 20:09', 'Chair', 1200, 'Mastercard', 'Adam Martin', 'Martin', 'TN', 'United States', '1/2/19 17:43', '1/4/19 20:01', 36.34333, -88.85028, 4, None),
#  (7, '1/5/19 2:42', 'Chair', 1200, 'Diners', 'Stacy Rourke', 'New York', 'NY', 'United States', '1/5/19 2:23', '1/5/19 4:59', 40.71417, -74.00639, 2, None),
#  (8, '1/2/19 9:16', 'Chair', 1200, 'Mastercard', 'Sean Davis', 'Shavano Park', 'TX', 'United States', '1/2/19 8:32', '1/5/19 9:05', 29.42389, -98.49333, 3, None),
#  (9, '1/5/19 10:08', 'Chair', 1200, 'Visa', 'Georgia Winston', 'Eagle', 'ID', 'United States', '11/11/18 15:53', '1/5/19 10:05', 43.69556, -116.35306, 1, None),
#  (10, '1/2/19 14:18', 'Chair', 1200, 'Visa', 'Richard Parker', 'Riverside', 'NJ', 'United States', '12/9/18 12:07', '1/5/19 11:01', 40.03222, -74.95778, 4, None),
#  (11, '1/5/19 11:37', 'Chair', 1200, 'Visa', 'Janet Feinbaum', 'Ottawa', 'ON', 'Canada', '1/5/19 9:35', '1/5/19 19:24', 45.4166667, -75.7, 3, None),
#  (12, '1/2/19 7:35', 'Chair', 1200, 'Diners', 'Hani Mercer', 'Salt Lake city', 'UT', 'United States', '12/30/18 5:44', '1/6/19 10:52', 40.76083, -111.89028, 3, None),
#  (13, '1/6/19 7:18', 'Chair', 1200, 'Visa', 'Asuman Winters', 'Chula Vista', 'CA', 'United States', '1/6/19 7:07', '1/7/19 7:08', 32.64, -117.08333, 2, None),
#  (14, '1/1/19 2:24', 'Chair', 1200, 'Visa', 'Lisa Owens', 'Sugar Land', 'TX', 'United States', '1/1/19 1:56', '1/7/19 10:52', 29.61944, -95.63472, 4, None),
#  (15, '1/7/19 8:08', 'Chair', 1200, 'Diners', 'Bryan Kerrene', 'New York', 'NY', 'United States', '1/7/19 7:39', '1/7/19 12:38', 40.71417, -74.00639, 1, None),
#  (16, '1/1/19 20:21', 'Chair', 1200, 'Visa', 'Maxine Klein', 'Morton', 'IL', 'United States', '10/24/18 6:48', '1/7/19 20:49', 40.61278, -89.45917, 4, None),
#  (17, '1/8/19 0:42', 'Chair', 1200, 'Visa', 'Buddy Dyer', 'Los Gatos', 'CA', 'United States', '1/8/19 0:28', '1/8/19 3:39', 37.22667, -121.97361, 2, None),
#  (18, '1/8/19 3:56', 'Chair', 1200, 'Mastercard', 'Katherine Klein', 'New York', 'NY', 'United States', '1/8/19 3:33', '1/8/19 6:19', 40.71417, -74.00639, 1, None),
#  (19, '1/8/19 3:16', 'Bed', 7500, 'Mastercard', 'Linda Smith', 'Miami', 'FL', 'United States', '1/8/19 3:06', '1/8/19 6:34', 25.77389, -80.19389, 4, None),
#  (20, '1/3/19 9:03', 'Chair', 1200, 'Diners', 'Sheila Egg', 'Brooklyn', 'NY', 'United States', '1/3/19 8:47', '1/8/19 10:38', 40.65, -73.95, 3, None),
#  (21, '1/6/19 7:46', 'Chair', 1200, 'Amex', 'Kelly Reilly', 'Reston', 'VA', 'United States', '1/6/19 7:30', '1/8/19 12:40', 38.96861, -77.34139, 3, None),
#  (22, '1/8/19 16:24', 'Chair', 1200, 'Visa', 'Jennifer Price', 'Phoenix', 'AZ', 'United States', '1/8/19 15:57', '1/8/19 18:30', 33.44833, -112.07333, 2, None),
#  (23, '1/9/19 6:39', 'Chair', 1200, 'Mastercard', 'Anneli Barker', 'houston', 'TX', 'United States', '1/9/19 5:09', '1/9/19 7:11', 29.76306, -95.36306, 2, None),
#  (24, '1/6/19 22:19', 'Bed', 7500, 'Amex', 'Regis Ritz', 'Pittsfield', 'VT', 'United States', '1/6/19 12:00', '1/9/19 10:05', 43.77222, -72.81333, 2, None),
#  (25, '1/6/19 23:00', 'Couch', 3600, 'Amex', 'Sophia Weimar', 'Pittsfield', 'VT', 'United States', '1/6/19 12:00', '1/9/19 10:05', 43.77222, -72.81333, 3, None),
#  (26, '1/7/19 7:44', 'Chair', 1200, 'Mastercard', 'Marie Jenner', 'Ball Ground', 'GA', 'United States', '1/7/19 5:35', '1/9/19 10:52', 34.33806, -84.37667, 4, None),
#  (27, '1/7/19 15:12', 'Couch', 3600, 'Visa', 'Anabela Taylor', 'Flossmoor', 'IL', 'United States', '1/5/19 19:55', '1/9/19 16:03', 41.54278, -87.68472, 4, None),
#  (28, '1/7/19 20:15', 'Chair', 1200, 'Amex', 'Nicole Custer', 'Houston', 'TX', 'United States', '1/7/19 17:17', '1/9/19 20:02', 29.76306, -95.36306, 2, None),
#  (29, '1/3/19 10:11', 'Couch', 3600, 'Visa', 'Christiane Hansen', 'Delray Beach', 'FL', 'United States', '1/3/19 9:27', '1/10/19 9:46', 26.46111, -80.07306, 1, None),
#  (30, '1/10/19 12:57', 'Couch', 3600, 'Amex', 'Vanessa Kruth', 'Sandy Springs', 'GA', 'United States', '2/7/07 20:16', '1/10/19 14:09', 33.92417, -84.37861, 4, None),
#  (31, '1/10/19 12:05', 'Chair', 1200, 'Visa', 'Anna Karina', 'Fort Lauderdale', 'FL', 'United States', '7/1/18 12:53', '1/10/19 16:33', 26.12194, -80.14361, 2, None),
#  (32, '1/10/19 14:56', 'Chair', 1200, 'Visa', 'Angela Lansbury', 'Ankeny', 'IA', 'United States', '1/8/19 3:06', '1/10/19 19:41', 41.72972, -93.60556, 4, None),
#  (33, '1/7/19 10:01', 'Chair', 1200, 'Visa', 'Darren Jones', 'Pittsboro', 'NC', 'United States', '1/7/19 9:04', '1/10/19 20:02', 35.72, -79.1775, 2, None),
#  (34, '1/1/19 1:26', 'Bed', 7500, 'Mastercard', 'Nikki Sixx', 'New Rochelle', 'NY', 'United States', '1/1/19 0:58', '1/10/19 21:31', 40.91139, -73.78278, 3, None),
#  (35, '1/10/19 21:38', 'Chair', 1200, 'Visa', 'Anushka Shetty', 'Maple Ridge District Municipality', 'BC', 'Canada', '1/10/19 21:17', '1/11/19 19:32', 49.25, -122.5, 4, None),
#  (36, '1/7/19 6:18', 'Chair', 1200, 'Mastercard', 'Barney June', 'Beachwood', 'OH', 'United States', '2/23/06 11:56', '1/11/19 19:35', 41.46444, -81.50889, 1, None),
#  (37, '1/4/19 8:39', 'Couch', 3600, 'Diners', 'Walter Baybars', 'Prince Albert', 'SK', 'Canada', '1/3/19 17:17', '1/11/19 21:05', 53.2, -105.75, 2, None),
#  (38, '1/12/19 3:25', 'Chair', 1200, 'Mastercard', 'Chrissy Hines', 'W Lebanon', 'NH', 'United States', '1/12/19 3:12', '1/12/19 3:22', 43.64917, -72.31083, 4, None),
#  (39, '1/8/19 15:16', 'Bed', 7500, 'Visa', 'Dottie Pang', 'Woodsboro', 'MD', 'United States', '1/8/19 14:56', '1/12/19 9:29', 39.53306, -77.315, 3, None),
#  (40, '1/7/19 20:22', 'Chair', 1200, 'Visa', 'Gina Lindsey', 'Red Deer', 'AB', 'Canada', '11/23/18 19:30', '1/12/19 12:24', 52.2666667, -113.8, 3, None),
#  (41, '1/2/19 22:00', 'Chair', 1200, 'Diners', 'Lynne Ford', 'Memphis', 'TN', 'United States', '1/2/19 21:04', '1/12/19 13:18', 35.14944, -90.04889, 2, None),
#  (42, '1/8/19 20:32', 'Chair', 1200, 'Visa', 'Ju Kim', 'Calgary', 'AB', 'Canada', '1/8/19 20:21', '1/12/19 14:07', 51.0833333, -114.0833333, 1, None),
#  (43, '1/8/19 13:34', 'Chair', 1200, 'Visa', 'Bruce Leider', 'Belleville', 'ON', 'Canada', '1/6/19 14:38', '1/12/19 18:31', 44.1666667, -77.3833333, 1, None),
#  (44, '1/11/19 13:08', 'Chair', 1200, 'Visa', 'Rosa Markus', 'Cincinnati', 'OH', 'United States', '1/11/19 12:38', '1/12/19 18:44', 39.16194, -84.45694, 2, None),
#  (45, '1/12/19 19:04', 'Chair', 1200, 'Visa', 'Lydia Franklin', 'Comox', 'BC', 'Canada', '9/20/18 20:53', '1/12/19 19:01', 49.6833333, -124.9333333, 4, None),
#  (46, '1/13/19 6:13', 'Chair', 1200, 'Visa', 'Bobby Gitte', 'Staten Island', 'NY', 'United States', '1/13/19 5:17', '1/13/19 7:33', 40.63667, -74.15917, 2, None),
#  (47, '1/2/19 11:41', 'Chair', 1200, 'Visa', 'Crystal Bale', 'Farmington', 'MI', 'United States', '1/1/19 12:00', '1/13/19 18:34', 42.46444, -83.37639, 4, None),
#  (48, '1/7/19 19:50', 'Chair', 1200, 'Diners', 'Delphine Sanders', 'Santa Monica', 'CA', 'United States', '1/3/19 12:04', '1/13/19 20:17', 34.01944, -118.49028, 3, None),
#  (49, '1/1/19 20:28', 'Chair', 1200, 'Visa', 'Nathalie Desai', 'Calgary', 'AB', 'Canada', '1/1/19 20:11', '1/13/19 21:11', 51.0833333, -114.0833333, 1, None),
#  (50, '1/3/19 15:22', 'Chair', 1200, 'Mastercard', 'Lindi George', 'Vancouver', 'BC', 'Canada', '2/20/18 22:45', '1/13/19 23:02', 49.25, -123.1333333, 1, None),
#  (51, '1/12/19 3:03', 'Couch', 3600, 'Mastercard', 'Valda Frank', 'Irvine', 'CA', 'United States', '1/12/19 2:48', '1/14/19 1:07', 33.66944, -117.82222, 2, None),
#  (52, '1/13/19 11:26', 'Chair', 1200, 'Visa', 'Clare Voyant', 'Keller', 'VA', 'United States', '1/13/19 11:15', '1/14/19 2:39', 37.61917, -75.76417, 2, None),
#  (53, '1/14/19 4:54', 'Chair', 1200, 'Mastercard', 'Zena Warrior', 'Honolulu', 'HI', 'United States', '1/14/19 4:34', '1/14/19 4:43', 21.30694, -157.85833, 1, None),
#  (54, '1/3/19 13:56', 'Chair', 1200, 'Visa', 'Rennae Isard', 'Amelia Island', 'FL', 'United States', '1/3/19 12:30', '1/14/19 13:03', 30.66944, -81.46278, 3, None),
#  (55, '1/3/19 2:24', 'Bed', 7200, 'Visa', 'Lisa Owens', 'Sugar Land', 'TX', 'United States', '1/1/19 1:56', '1/7/19 10:52', 29.61944, -95.63472, 4, None),
#  (56, '1/5/19 8:08', 'Bed', 7200, 'Diners', 'Bryan Kerrene', 'New York', 'NY', 'United States', '1/7/19 7:39', '1/7/19 12:38', 40.71417, -74.00639, 1, None),
#  (57, '1/5/19 20:21', 'Bed', 7200, 'Visa', 'Maxine Klein', 'Morton', 'IL', 'United States', '10/24/18 6:48', '1/7/19 20:49', 40.61278, -89.45917, 4, None),
#  (58, '1/8/19 0:45', 'Bed', 7200, 'Visa', 'Buddy Dyer', 'Los Gatos', 'CA', 'United States', '1/8/19 0:28', '1/8/19 3:39', 37.22667, -121.97361, 2, None),
#  (59, '1/6/19 12:24', 'Couch', 5000, 'Visa', 'Lisa Owens', 'Sugar Land', 'TX', 'United States', '1/1/19 1:56', '1/7/19 10:52', 29.61944, -95.63472, 4, None),
#  (60, '1/9/19 9:24', 'Bed', 6000, 'Visa', 'Lisa Owens', 'Sugar Land', 'TX', 'United States', '1/1/19 1:56', '1/7/19 10:52', 29.61944, -95.63472, 4, None)]

# %%
#creating supplier table

# %%sql
CREATE TABLE suppliers(id INTEGER PRIMARY KEY,
                      Name TEXT,
                      Country TEXT);
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# (MySQLdb.OperationalError) (1050, "Table 'suppliers' already exists")
# [SQL: CREATE TABLE suppliers(id INTEGER PRIMARY KEY,
#                       Name TEXT,
#                       Country TEXT);]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
#adding values in supplier table

# %%sql
INSERT INTO suppliers(id,Name, Country) VALUES ('1','Ikea', 'Sweden');
INSERT INTO suppliers(id,Name, Country) VALUES('2','Rosewood', 'Thailand');
INSERT INTO suppliers(id,Name, Country) VALUES('3','BoConcept', 'Denmark');

INSERT INTO suppliers(id,Name, Country) VALUES('4','AllModern', 'United States');
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# (MySQLdb.IntegrityError) (1062, "Duplicate entry '1' for key 'suppliers.PRIMARY'")
# [SQL: INSERT INTO suppliers(id,Name, Country) VALUES ('1','Ikea', 'Sweden');]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
#select supplier table from database

# %%sql
SELECT * FROM suppliers;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 4 rows affected.
# [(1, 'Ikea', 'Sweden'),
#  (2, 'Rosewood', 'Thailand'),
#  (3, 'BoConcept', 'Denmark'),
#  (4, 'AllModern', 'United States')]

# %%
#TOTAL SALES BY PRODUCT

# %%sql
SELECT product as Product, (SUM(price)) AS Total_Sales 
FROM sales GROUP BY product ORDER BY Total_Sales desc;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 3 rows affected.
# [('Bed', Decimal('64800')),
#  ('Chair', Decimal('51600')),
#  ('Couch', Decimal('30200'))]

# %%
#TOTAL PURCHASES BY CUSTOMER WHO SPENT MORE THAN $5000

# %%sql
SELECT name AS Customer_Name, (SUM(price)) AS Total_Purchases 
FROM sales GROUP BY name HAVING SUM(price) > 5000 
ORDER BY SUM(price) desc;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 8 rows affected.
# [('Lisa Owens', Decimal('19400')),
#  ('Bryan Kerrene', Decimal('8400')),
#  ('Maxine Klein', Decimal('8400')),
#  ('Buddy Dyer', Decimal('8400')),
#  ('Linda Smith', Decimal('7500')),
#  ('Regis Ritz', Decimal('7500')),
#  ('Nikki Sixx', Decimal('7500')),
#  ('Dottie Pang', Decimal('7500'))]

# %%
#SALES AND SUPPLIER TABLES JOINED, LIMITED TO PURCHASES > $1500

# %%sql
SELECT s.transaction_date as Date, s.name as Customer, s.product as Product, s.price as Price, su.Name as Supplier, su.Country 
FROM sales s INNER JOIN suppliers su 
ON su.id = s.supplier 
WHERE price > 1500 ORDER BY price desc;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 17 rows affected.
# [('1/8/19 3:16', 'Linda Smith', 'Bed', 7500, 'AllModern', 'United States'),
#  ('1/6/19 22:19', 'Regis Ritz', 'Bed', 7500, 'Rosewood', 'Thailand'),
#  ('1/1/19 1:26', 'Nikki Sixx', 'Bed', 7500, 'BoConcept', 'Denmark'),
#  ('1/8/19 15:16', 'Dottie Pang', 'Bed', 7500, 'BoConcept', 'Denmark'),
#  ('1/3/19 2:24', 'Lisa Owens', 'Bed', 7200, 'AllModern', 'United States'),
#  ('1/5/19 8:08', 'Bryan Kerrene', 'Bed', 7200, 'Ikea', 'Sweden'),
#  ('1/5/19 20:21', 'Maxine Klein', 'Bed', 7200, 'AllModern', 'United States'),
#  ('1/8/19 0:45', 'Buddy Dyer', 'Bed', 7200, 'Rosewood', 'Thailand'),
#  ('1/9/19 9:24', 'Lisa Owens', 'Bed', 6000, 'AllModern', 'United States'),
#  ('1/6/19 12:24', 'Lisa Owens', 'Couch', 5000, 'AllModern', 'United States'),
#  ('1/4/19 12:56', 'Gerd Winslow', 'Couch', 3600, 'Ikea', 'Sweden'),
#  ('1/6/19 23:00', 'Sophia Weimar', 'Couch', 3600, 'BoConcept', 'Denmark'),
#  ('1/7/19 15:12', 'Anabela Taylor', 'Couch', 3600, 'AllModern', 'United States'),
#  ('1/3/19 10:11', 'Christiane Hansen', 'Couch', 3600, 'Ikea', 'Sweden'),
#  ('1/10/19 12:57', 'Vanessa Kruth', 'Couch', 3600, 'AllModern', 'United States'),
#  ('1/4/19 8:39', 'Walter Baybars', 'Couch', 3600, 'Rosewood', 'Thailand'),
#  ('1/12/19 3:03', 'Valda Frank', 'Couch', 3600, 'Rosewood', 'Thailand')]

# %%
#CATEGORIZE CUSTOMER VALUE BY TOTAL LIFETIME PURCHASES

# %%sql
SELECT name AS Customer_Name, (SUM(price)) AS Total_Purchases,
CASE 
    WHEN SUM(price) >= 5000 THEN 'High'
    WHEN SUM(price) >= 2000 THEN 'Medium'
    ELSE 'Standard'
  END Category  
FROM sales 
GROUP BY name ORDER BY SUM(price) desc;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 54 rows affected.
# [('Lisa Owens', Decimal('19400'), 'High'),
#  ('Bryan Kerrene', Decimal('8400'), 'High'),
#  ('Maxine Klein', Decimal('8400'), 'High'),
#  ('Buddy Dyer', Decimal('8400'), 'High'),
#  ('Regis Ritz', Decimal('7500'), 'High'),
#  ('Nikki Sixx', Decimal('7500'), 'High'),
#  ('Linda Smith', Decimal('7500'), 'High'),
#  ('Dottie Pang', Decimal('7500'), 'High'),
#  ('Sophia Weimar', Decimal('3600'), 'Medium'),
#  ('Gerd Winslow', Decimal('3600'), 'Medium'),
#  ('Anabela Taylor', Decimal('3600'), 'Medium'),
#  ('Christiane Hansen', Decimal('3600'), 'Medium'),
#  ('Vanessa Kruth', Decimal('3600'), 'Medium'),
#  ('Walter Baybars', Decimal('3600'), 'Medium'),
#  ('Valda Frank', Decimal('3600'), 'Medium'),
#  ('Stacy Rourke', Decimal('1200'), 'Standard'),
#  ('Sean Davis', Decimal('1200'), 'Standard'),
#  ('Georgia Winston', Decimal('1200'), 'Standard'),
#  ('Richard Parker', Decimal('1200'), 'Standard'),
#  ('Janet Feinbaum', Decimal('1200'), 'Standard'),
#  ('Hani Mercer', Decimal('1200'), 'Standard'),
#  ('Asuman Winters', Decimal('1200'), 'Standard'),
#  ('Katherine Klein', Decimal('1200'), 'Standard'),
#  ('Sheila Egg', Decimal('1200'), 'Standard'),
#  ('Kelly Reilly', Decimal('1200'), 'Standard'),
#  ('Anneli Barker', Decimal('1200'), 'Standard'),
#  ('Marie Jenner', Decimal('1200'), 'Standard'),
#  ('Jennifer Price', Decimal('1200'), 'Standard'),
#  ('Bettina Schmidt', Decimal('1200'), 'Standard'),
#  ('Federica Villanueva', Decimal('1200'), 'Standard'),
#  ('Anna Karina', Decimal('1200'), 'Standard'),
#  ('Angela Lansbury', Decimal('1200'), 'Standard'),
#  ('Darren Jones', Decimal('1200'), 'Standard'),
#  ('Nicole Custer', Decimal('1200'), 'Standard'),
#  ('Anushka Shetty', Decimal('1200'), 'Standard'),
#  ('Barney June', Decimal('1200'), 'Standard'),
#  ('Laurence Arabia', Decimal('1200'), 'Standard'),
#  ('Chrissy Hines', Decimal('1200'), 'Standard'),
#  ('Fleur Barnes', Decimal('1200'), 'Standard'),
#  ('Gina Lindsey', Decimal('1200'), 'Standard'),
#  ('Lynne Ford', Decimal('1200'), 'Standard'),
#  ('Ju Kim', Decimal('1200'), 'Standard'),
#  ('Bruce Leider', Decimal('1200'), 'Standard'),
#  ('Rosa Markus', Decimal('1200'), 'Standard'),
#  ('Lydia Franklin', Decimal('1200'), 'Standard'),
#  ('Bobby Gitte', Decimal('1200'), 'Standard'),
#  ('Crystal Bale', Decimal('1200'), 'Standard'),
#  ('Delphine Sanders', Decimal('1200'), 'Standard'),
#  ('Nathalie Desai', Decimal('1200'), 'Standard'),
#  ('Lindi George', Decimal('1200'), 'Standard'),
#  ('Adam Martin', Decimal('1200'), 'Standard'),
#  ('Clare Voyant', Decimal('1200'), 'Standard'),
#  ('Zena Warrior', Decimal('1200'), 'Standard'),
#  ('Rennae Isard', Decimal('1200'), 'Standard')]

# %%
#AVERAGE PURCHASE OF CUSTOMERS BY THEIR STATE, AVG PURCHASES > $2500

# %%sql

SELECT state AS State_Province, (ROUND(AVG(price))) AS Average_Purchase 
FROM sales GROUP BY state HAVING ROUND(AVG(price)) > 2500 
ORDER BY ROUND(AVG(price)) desc;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 9 rows affected.
# [('MD', Decimal('7500')),
#  ('VT', Decimal('5550')),
#  ('AL', Decimal('3600')),
#  ('SK', Decimal('3600')),
#  ('FL', Decimal('3375')),
#  ('IL', Decimal('3300')),
#  ('TX', Decimal('3286')),
#  ('NY', Decimal('2957')),
#  ('CA', Decimal('2880'))]

# %%
#TOTAL SALES BY SUPPLIER

# %%sql
SELECT su.Name as Supplier, su.Country, (SUM(s.price)) as Total_Sales 
FROM suppliers su JOIN sales s 
ON su.id = s.supplier 
GROUP BY su.Name;
# Out:
#  * mysql+mysqldb://Akil:***@localhost/furniture_sales_db
# 4 rows affected.
# [('Rosewood', 'Thailand', Decimal('38700')),
#  ('BoConcept', 'Denmark', Decimal('30600')),
#  ('Ikea', 'Sweden', Decimal('25200')),
#  ('AllModern', 'United States', Decimal('52100'))]
